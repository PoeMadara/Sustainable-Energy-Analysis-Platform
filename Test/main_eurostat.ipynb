# %%
import pandas as pd

# Cargar el archivo Excel
file_path = 'Energy_productivity_short.xlsx'

# Leer el archivo Excel
df = pd.read_excel(file_path, sheet_name=None)

# Mostrar los nombres de las hojas
sheet_names = df.keys()
print("Sheet names:", sheet_names)

# Mostrar las columnas y los datos para cada hoja
for sheet_name in sheet_names:
    print(f"\nSheet: {sheet_name}")
    print(df[sheet_name].head(20))
# Out:
# Sheet names: dict_keys(['Summary', 'Structure', 'Sheet 1'])
#
# Sheet: Summary
#                                       Unnamed: 0               Unnamed: 1  \
# 0                                            NaN                      NaN
# 1                                            NaN                      NaN
# 2                                            NaN                      NaN
# 3                                            NaN                      NaN
# 4   Energy productivity [nrg_ind_ep$defaultview]                      NaN
# 5                              Open product page     Open in Data Browser
# 6                                  Description:                         -
# 7                                            NaN                      NaN
# 8                          Last update of data:                       NaN
# 9                Last change of data structure:                       NaN
# 10                                           NaN                      NaN
# 11                                           NaN  Institutional source(s)
# 12                                           NaN                      NaN
# 13                                           NaN                      NaN
# 14                                           NaN        Source dataset(s)
# 15                                           NaN                      NaN
# 16                                           NaN                      NaN
# 17                                           NaN                 Contents
# 18                                           NaN                  Sheet 1
#
#                                            Unnamed: 2  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                           Eurostat
# 13                                                NaN
# 14                                                NaN
# 15  This data product is extracted from the follow...
# 16                                         nrg_ind_ep
# 17                                     Time frequency
# 18                                             Annual
#
#                                     Unnamed: 3         Unnamed: 4  \
# 0                                          NaN                NaN
# 1                                          NaN                NaN
# 2                                          NaN                NaN
# 3                                          NaN                NaN
# 4                                          NaN                NaN
# 5                                          NaN                NaN
# 6                                          NaN                NaN
# 7                                          NaN                NaN
# 8                             15/05/2024 23:00                NaN
# 9                             03/01/2024 23:00                NaN
# 10                                         NaN                NaN
# 11                                         NaN                NaN
# 12                                         NaN                NaN
# 13                                         NaN                NaN
# 14                                         NaN                NaN
# 15                                         NaN                NaN
# 16                         Energy productivity  Open product page
# 17                             Unit of measure                NaN
# 18  Euro per kilogram of oil equivalent (KGOE)                NaN
#
#               Unnamed: 5
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# 6                    NaN
# 7                    NaN
# 8                    NaN
# 9                    NaN
# 10                   NaN
# 11                   NaN
# 12                   NaN
# 13                   NaN
# 14                   NaN
# 15                   NaN
# 16  Open in Data Browser
# 17                   NaN
# 18                   NaN
#
# Sheet: Structure
#     Structure                       Unnamed: 1  \
# 0         NaN                        Dimension
# 1         NaN                            Label
# 2         NaN                   Time frequency
# 3         NaN                  Unit of measure
# 4         NaN  Geopolitical entity (reporting)
# 5         NaN  Geopolitical entity (reporting)
# 6         NaN  Geopolitical entity (reporting)
# 7         NaN  Geopolitical entity (reporting)
# 8         NaN  Geopolitical entity (reporting)
# 9         NaN  Geopolitical entity (reporting)
# 10        NaN  Geopolitical entity (reporting)
# 11        NaN  Geopolitical entity (reporting)
# 12        NaN  Geopolitical entity (reporting)
# 13        NaN  Geopolitical entity (reporting)
# 14        NaN  Geopolitical entity (reporting)
# 15        NaN  Geopolitical entity (reporting)
# 16        NaN  Geopolitical entity (reporting)
# 17        NaN  Geopolitical entity (reporting)
# 18        NaN  Geopolitical entity (reporting)
# 19        NaN  Geopolitical entity (reporting)
#
#                                     Unnamed: 2
# 0                                     Position
# 1                                        Label
# 2                                       Annual
# 3   Euro per kilogram of oil equivalent (KGOE)
# 4    European Union - 27 countries (from 2020)
# 5                                      Belgium
# 6                                     Bulgaria
# 7                                      Czechia
# 8                                      Denmark
# 9                                      Germany
# 10                                     Estonia
# 11                                     Ireland
# 12                                      Greece
# 13                                       Spain
# 14                                      France
# 15                                     Croatia
# 16                                       Italy
# 17                                      Cyprus
# 18                                      Latvia
# 19                                   Lithuania
#
# Sheet: Sheet 1
#    Data extracted on 16/10/2024 11:18:45 from [ESTAT]  \
# 0                                           Dataset:
# 1                                      Last updated:
# 2                                                 NaN
# 3                                      Time frequency
# 4                                     Unit of measure
# 5                                                 NaN
# 6                                                TIME
# 7                                        GEO (Labels)
# 8           European Union - 27 countries (from 2020)
# 9                                             Belgium
# 10                                           Bulgaria
# 11                                            Czechia
# 12                                            Denmark
# 13                                            Germany
# 14                                            Estonia
# 15                                            Ireland
# 16                                             Greece
# 17                                              Spain
# 18                                             France
# 19                                            Croatia
#
#                                       Unnamed: 1  \
# 0   Energy productivity [nrg_ind_ep$defaultview]
# 1                               15/05/2024 23:00
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                           2013
# 7                                            NaN
# 8                                          7.295
# 9                                          5.966
# 10                                         2.281
# 11                                         3.668
# 12                                         13.19
# 13                                          8.07
# 14                                         2.631
# 15                                        12.741
# 16                                         6.965
# 17                                         7.955
# 18                                         7.663
# 19                                         5.217
#
#                                     Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                                          NaN         NaN         NaN
# 1                                          NaN         NaN         NaN
# 2                                          NaN         NaN         NaN
# 3                                       Annual         NaN         NaN
# 4   Euro per kilogram of oil equivalent (KGOE)         NaN         NaN
# 5                                          NaN         NaN         NaN
# 6                                         2014    2015.000    2016.000
# 7                                          NaN         NaN         NaN
# 8                                        7.675       7.784       7.841
# 9                                        6.434       6.510       6.212
# 10                                       2.202       2.178       2.293
# 11                                       3.879       4.084       4.227
# 12                                      14.012      14.377      14.534
# 13                                       8.616       8.699       8.829
# 14                                       2.891       3.383       2.848
# 15                                      13.777      16.207      15.633
# 16                                       7.087       7.070       7.173
# 17                                       8.187       8.219       8.403
# 18                                       8.052       8.012       8.243
# 19                                       5.457       5.364       5.511
#
#     Unnamed: 5  Unnamed: 6  Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10
# 0          NaN         NaN         NaN        NaN        NaN         NaN
# 1          NaN         NaN         NaN        NaN        NaN         NaN
# 2          NaN         NaN         NaN        NaN        NaN         NaN
# 3          NaN         NaN         NaN        NaN        NaN         NaN
# 4          NaN         NaN         NaN        NaN        NaN         NaN
# 5          NaN         NaN         NaN        NaN        NaN         NaN
# 6     2017.000    2018.000    2019.000       2020       2021        2022
# 7          NaN         NaN         NaN        NaN        NaN         NaN
# 8        7.909       8.142       8.365      8.596      8.592       9.309
# 9        6.236       6.341       6.454      6.795      6.526       7.221
# 10       2.276       2.346       2.466      2.495      2.469       2.532
# 11       4.261       4.381       4.588      4.616      4.509       4.712
# 12      14.955      15.176      15.731     16.763      17.02       17.75
# 13       9.026       9.337       9.652     10.038      9.955      10.635
# 14       3.041       3.267       4.014      4.233      4.429       4.192
# 15      17.228      18.581      19.505     22.578     25.039      26.774
# 16       6.936       7.189       7.310      7.829      8.032       8.317
# 17       8.293       8.475       8.852      8.918      8.953       9.257
# 18       8.428       8.617       8.885      9.273      9.121      10.278
# 19       5.501       5.790       5.910      5.725      6.178       6.761
# c:\Users\Carlos\anaconda3\envs\project3\Lib\site-packages\openpyxl\styles\stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
